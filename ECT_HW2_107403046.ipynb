# %% [markdown]
# ## 第一部分

# %% [markdown]
# ### 1.

# %%
import pandas as pd
import numpy as np
ad = pd.read_csv('Desktop\ECT_HW2\Advertising.csv', index_col = "Date")
ad.head(5)
# Out:
#                   TV  newspaper    radio    sales
# Date
# 2018-01-01  230100.0    69200.0  37800.0  22100.0
# 2018-01-02   44500.0    45100.0  39300.0  10400.0
# 2018-01-03   17200.0    69300.0  45900.0   9300.0
# 2018-01-04  151500.0    58500.0  41300.0  18500.0
# 2018-01-05  180800.0    58400.0  10800.0  12900.0

# %% [markdown]
# ### 2.

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 2018-01-01 to 2018-07-19
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   newspaper  200 non-null    float64
#  2   radio      200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8+ KB

# %% [markdown]
# 2.a. TV, newspaper, radio, sales 欄位皆為 可容納64位元的float浮點數

# %% [markdown]
# 2.b. 否

# %% [markdown]
# ### 3.a.

# %%
ad.describe()
# Out:
#                   TV      newspaper         radio         sales
# count     200.000000     200.000000    200.000000    200.000000
# mean   147042.500000   30554.000000  23264.000000  14022.500000
# std     85854.236315   21778.620839  14846.809176   5217.456566
# min       700.000000     300.000000      0.000000   1600.000000
# 25%     74375.000000   12750.000000   9975.000000  10375.000000
# 50%    149750.000000   25750.000000  22900.000000  12900.000000
# 75%    218825.000000   45100.000000  36525.000000  17400.000000
# max    296400.000000  114000.000000  49600.000000  27000.000000

# %%
print("各欄位資料筆數 :\n",ad.count(),"\n")
print("各欄位資料平均值 :\n",ad.mean(),"\n")
print("各欄位資料標準差 :\n",ad.std(),"\n")
print("各欄位資料最小值 :\n",ad.min(),"\n")
print("各欄位資料最大值 :\n",ad.max(),"\n")
print("各欄位資料第1四分位數 :\n",ad.quantile(q=0.25),"\n")
print("各欄位資料第2四分位數 :\n",ad.median(),"\n")
print("各欄位資料第3四分位數 :\n",ad.quantile(q=0.75))
# Out:
# 各欄位資料筆數 :
#  TV           200
# newspaper    200
# radio        200
# sales        200
# dtype: int64
#
# 各欄位資料平均值 :
#  TV           147042.5
# newspaper     30554.0
# radio         23264.0
# sales         14022.5
# dtype: float64
#
# 各欄位資料標準差 :
#  TV           85854.236315
# newspaper    21778.620839
# radio        14846.809176
# sales         5217.456566
# dtype: float64
#
# 各欄位資料最小值 :
#  TV            700.0
# newspaper     300.0
# radio           0.0
# sales        1600.0
# dtype: float64
#
# 各欄位資料最大值 :
#  TV           296400.0
# newspaper    114000.0
# radio         49600.0
# sales         27000.0
# dtype: float64
#
# 各欄位資料第1四分位數 :
#  TV           74375.0
# newspaper    12750.0
# radio         9975.0
# sales        10375.0
# Name: 0.25, dtype: float64
#
# 各欄位資料第2四分位數 :
#  TV           149750.0
# newspaper     25750.0
# radio         22900.0
# sales         12900.0
# dtype: float64
#
# 各欄位資料第3四分位數 :
#  TV           218825.0
# newspaper     45100.0
# radio         36525.0
# ...

# %% [markdown]
# ### 3.b.

# %%
data = pd.DataFrame(ad.quantile(q=0.1))
for i in range (2,11):
    data[i*0.1]= ad.quantile(q=0.1*i)
data.T
# Out:
#            TV  newspaper    radio    sales
# 0.1   24880.0     5990.0   3400.0   7960.0
# 0.2   59180.0     9380.0   7680.0   9700.0
# 0.3   86750.0    15970.0  11940.0  10870.0
# 0.4  119000.0    21320.0  17120.0  11800.0
# 0.5  149750.0    25750.0  22900.0  12900.0
# 0.6  186060.0    32700.0  27860.0  14800.0
# 0.7  210730.0    39110.0  33500.0  16600.0
# 0.8  228540.0    49640.0  38920.0  18920.0
# 0.9  261440.0    59070.0  43520.0  21710.0
# 1.0  296400.0   114000.0  49600.0  27000.0

# %% [markdown]
# ### 4.

# %%
tv=ad[['TV']]
tv.plot(kind="bar")

np=ad[['newspaper']]
np.plot(kind="bar")

rd=ad[['radio']]
rd.plot(kind="bar")

sl=ad[['sales']]
sl.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### 5.

# %%
pd.plotting.scatter_matrix(ad, alpha=0.2)
# Out:
# array([[<AxesSubplot:xlabel='TV', ylabel='TV'>,
#         <AxesSubplot:xlabel='newspaper', ylabel='TV'>,
#         <AxesSubplot:xlabel='radio', ylabel='TV'>,
#         <AxesSubplot:xlabel='sales', ylabel='TV'>],
#        [<AxesSubplot:xlabel='TV', ylabel='newspaper'>,
#         <AxesSubplot:xlabel='newspaper', ylabel='newspaper'>,
#         <AxesSubplot:xlabel='radio', ylabel='newspaper'>,
#         <AxesSubplot:xlabel='sales', ylabel='newspaper'>],
#        [<AxesSubplot:xlabel='TV', ylabel='radio'>,
#         <AxesSubplot:xlabel='newspaper', ylabel='radio'>,
#         <AxesSubplot:xlabel='radio', ylabel='radio'>,
#         <AxesSubplot:xlabel='sales', ylabel='radio'>],
#        [<AxesSubplot:xlabel='TV', ylabel='sales'>,
#         <AxesSubplot:xlabel='newspaper', ylabel='sales'>,
#         <AxesSubplot:xlabel='radio', ylabel='sales'>,
#         <AxesSubplot:xlabel='sales', ylabel='sales'>]], dtype=object)

# %% [markdown]
# TV的觸及數與sales呈正相關
#
# newspaper的觸及數與sales關係較不明顯
#
# radio的觸及數與sales呈正相關但與TV與sales的關係相比較不集中

# %% [markdown]
# ### 6.

# %% [markdown]
# ### a.

# %%
ad.index = pd.to_datetime(ad.index)
ad.head()
# Out:
#                   TV  newspaper    radio    sales
# Date
# 2018-01-01  230100.0    69200.0  37800.0  22100.0
# 2018-01-02   44500.0    45100.0  39300.0  10400.0
# 2018-01-03   17200.0    69300.0  45900.0   9300.0
# 2018-01-04  151500.0    58500.0  41300.0  18500.0
# 2018-01-05  180800.0    58400.0  10800.0  12900.0

# %% [markdown]
# ### b.

# %%
ad.resample('M').sum().to_period('M').head(10)
# Out:
#                 TV  newspaper     radio     sales
# Date
# 2018-01  4404000.0  1173100.0  753900.0  424900.0
# 2018-02  4693800.0   824900.0  696600.0  434200.0
# 2018-03  3909100.0   923200.0  799900.0  428900.0
# 2018-04  4823300.0  1022600.0  649700.0  440700.0
# 2018-05  3973700.0   926200.0  800300.0  410000.0
# 2018-06  4674400.0   834200.0  573000.0  395800.0
# 2018-07  2930200.0   406600.0  379400.0  270000.0

# %% [markdown]
# ### c.

# %%
sm = ad.drop(['sales'],axis = 1)
sm.resample('M').sum().to_period('M')
sm.groupby(['2018-01'],['TV']).plot(kind="pie")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-8b63d59c3258> in <module>
#       1 sm = ad.drop(['sales'],axis = 1)
#       2 sm.resample('M').sum().to_period('M')
# ----> 3 sm.groupby(['2018-01'],['TV']).plot(kind="pie")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6507         if level is None and by is None:
#    6508             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 6509         axis = self._get_axis_number(axis)
#    6510
#    6511         return DataFrameGroupBy(
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     366     def _get_axis_number(cls, axis: Axis) -> int:
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
# ...

# %% [markdown]
# ### d.

# %%
sbc = sm.resample('M').sum().to_period('M').plot.bar(stacked=True)

# %% [markdown]
# ### e.

# %%
ad['sales'].resample('M').sum().to_period('M').plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### f.

# %%
line = sm.resample('M').sum().to_period('M').plot(kind='line')
line.set_title('The hits of social media line chart')
line.set_ylabel('Hits')
# Out:
# Text(0, 0.5, 'Hits')

# %% [markdown]
# ## 第二部分

# %% [markdown]
# ### 1.

# %%
sales = pd.read_csv('Desktop\ECT_HW2\sales.csv')
sales07 = pd.read_csv('Desktop\ECT_HW2\sales2007.csv')
df = pd.concat([sales,sales07])
df
# Out:
#      Year       Product line      Product type                      Product  \
# 0    2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 1    2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2    2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3    2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4    2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# ..    ...                ...               ...                          ...
# 355  2007  Camping Equipment      Cooking Gear           TrailChef Utensils
# 356  2007  Camping Equipment      Cooking Gear           TrailChef Utensils
# 357  2007  Camping Equipment      Cooking Gear           TrailChef Utensils
# 358  2007  Camping Equipment      Cooking Gear           TrailChef Utensils
# 359  2007  Camping Equipment      Cooking Gear           TrailChef Utensils
#
# ...

# %% [markdown]
# ### 2.

# %%
df.groupby(['Product line']).size()
# Out:
# Product line
# Camping Equipment           2912
# Golf Equipment               615
# Mountaineering Equipment     729
# Outdoor Protection          1604
# dtype: int64

# %% [markdown]
# ### 3.

# %%
data = df.groupby(['Retailer country']).sum()
revdata = data.drop(['Year','Planned revenue','Product cost','Quantity','Unit cost','Unit price','Gross profit','Unit sale price'],axis = 1)
revdata
# Out:
#                        Revenue
# Retailer country
# Australia         1.441897e+07
# Austria           1.536226e+07
# Belgium           1.335291e+07
# Brazil            1.583751e+07
# Canada            3.682538e+07
# China             4.090920e+07
# Denmark           7.947803e+06
# Finland           2.553192e+07
# France            3.390698e+07
# Germany           3.307413e+07
# Italy             2.446368e+07
# Japan             4.327536e+07
# Korea             2.991737e+07
# Mexico            2.498386e+07
# Netherlands       2.362475e+07
# Singapore         2.713914e+07
# Spain             2.230262e+07
# Sweden            9.143315e+06
# Switzerland       1.008921e+07
# United Kingdom    3.764171e+07
# United States     1.010946e+08

# %%
revdata['Revenue']>30000000
# Out:
# Retailer country
# Australia         False
# Austria           False
# Belgium           False
# Brazil            False
# Canada             True
# China              True
# Denmark           False
# Finland           False
# France             True
# Germany            True
# Italy             False
# Japan              True
# Korea             False
# Mexico            False
# Netherlands       False
# Singapore         False
# Spain             False
# Sweden            False
# Switzerland       False
# United Kingdom     True
# United States      True
# Name: Revenue, dtype: bool

# %% [markdown]
# Canada, China, France, Germany, Japan, United Kingdom, United States 的 Revenue>30,000,000

# %% [markdown]
# ### 4.

# %%
prodata = df.groupby(['Year','Product']).sum()
prodata
# Out:
#                                 Revenue  Planned revenue  Product cost  \
# Year Product
# 2004 Aloe Relief              435597.19        436547.75     160460.16
#      BugShield Extreme       8828495.90       8984774.40    3190053.68
#      BugShield Lotion        2571144.03       2616700.45     884328.20
#      BugShield Lotion Lite   1300323.43       1292183.27     353400.52
#      BugShield Natural       3538244.82       3573188.76    1134685.56
# ...                                 ...              ...           ...
# 2007 TrailChef Kettle        5550018.08       6254941.21    2383376.94
#      TrailChef Kitchen Kit   4275048.82       4218941.08    2882836.17
#      TrailChef Single Flame  9666743.10       9431774.10    6803296.68
#      TrailChef Utensils      3288640.03       3619137.44    1713884.00
#      TrailChef Water Bag     5936527.10       5279053.02    2502280.97
#
#                               Quantity    Unit cost  Unit price  Gross profit  \
# Year Product
# ...

# %% [markdown]
# ### 5.

# %%
prodata.nlargest(3,'Quantity')
# Out:
#                              Revenue  Planned revenue  Product cost  \
# Year Product
# 2004 BugShield Extreme    8828495.90       8984774.40    3190053.68
# 2006 TrailChef Water Bag  7901859.28       7374568.08    3358393.64
# 2005 TrailChef Water Bag  6978659.08       6460174.61    2941961.21
#
#                            Quantity   Unit cost  Unit price  Gross profit  \
# Year Product
# 2004 BugShield Extreme    1318204.0  154.880000      448.00    5395788.62
# 2006 TrailChef Water Bag  1260914.0  131.015671      309.73    3608610.46
# 2005 TrailChef Water Bag  1124877.0  179.720913      428.35    3083933.05
#
#                           Unit sale price
# Year Product
# 2004 BugShield Extreme         417.441500
# 2006 TrailChef Water Bag       276.659279
# 2005 TrailChef Water Bag       375.908477

# %% [markdown]
# ### 6.

# %%
df['Gross margin'] = df['Gross profit']/df['Revenue']
df
# Out:
#      Year       Product line      Product type                      Product  \
# 0    2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 1    2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2    2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3    2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4    2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# ..    ...                ...               ...                          ...
# 355  2007  Camping Equipment      Cooking Gear           TrailChef Utensils
# 356  2007  Camping Equipment      Cooking Gear           TrailChef Utensils
# 357  2007  Camping Equipment      Cooking Gear           TrailChef Utensils
# 358  2007  Camping Equipment      Cooking Gear           TrailChef Utensils
# 359  2007  Camping Equipment      Cooking Gear           TrailChef Utensils
#
# ...
